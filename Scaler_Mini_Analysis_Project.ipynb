# %%
import pandas as pd

# %%
df = pd.read_excel('/content/Sample - Superstore (15).xls')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = pd.read_excel('/content/Sample - Superstore (15).xls')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.head(10)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
df.tail(10)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9984    9985  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985    9986  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987    9988  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 9984    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# 9985    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# ...

# %%
#analysis

#aggregate on the basis of state

df.groupby("State")['Sales'].sum()
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %%
df.groupby("State")['Sales'].mean()
# Out:
# State
# Alabama                  319.846557
# Arizona                  157.508933
# Arkansas                 194.635500
# California               228.729451
# Colorado                 176.418231
# Connecticut              163.223866
# Delaware                 285.948635
# District of Columbia     286.502000
# Florida                  233.612815
# Georgia                  266.825217
# Idaho                    208.689810
# Illinois                 162.939230
# Indiana                  359.431946
# Iowa                     152.658667
# Kansas                   121.429583
# Kentucky                 263.250000
# Louisiana                219.453095
# Maine                    158.816250
# Maryland                 225.766886
# Massachusetts            212.106919
# Michigan                 299.096525
# Minnesota                335.541011
# Mississippi              203.232830
# Missouri                 336.441667
# Montana                  372.623467
# Nebraska                 196.445526
# ...

# %%
df.groupby("State")['Sales'].median()
# Out:
# State
# Alabama                   70.980
# Arizona                   61.512
# Arkansas                  54.420
# California                61.020
# Colorado                  51.016
# Connecticut               50.000
# Delaware                  67.005
# District of Columbia      35.800
# Florida                   41.472
# Georgia                   70.955
# Idaho                     89.970
# Illinois                  36.568
# Indiana                   70.080
# Iowa                      33.465
# Kansas                    63.980
# Kentucky                  76.300
# Louisiana                 64.140
# Maine                    105.720
# Maryland                  89.820
# Massachusetts             63.200
# Michigan                  85.520
# Minnesota                 50.400
# Mississippi               77.560
# Missouri                  57.685
# Montana                   63.980
# Nebraska                  34.200
# Nevada                    79.140
# New Hampshire             68.620
# ...

# %%
df.groupby("State")['Sales'].describe()
# Out:
#                        count         mean          std       min         25%  \
# State
# Alabama                 61.0   319.846557   545.761807     3.620    19.56000
# Arizona                224.0   157.508933   249.710692     1.408    15.16400
# Arkansas                60.0   194.635500   316.405669     4.300    19.77750
# California            2001.0   228.729451   491.005264     0.990    19.76000
# Colorado               182.0   176.418231   324.415072     1.080    15.16000
# Connecticut             82.0   163.223866   251.732268     3.520    14.71250
# Delaware                96.0   285.948635  1112.818485     3.380    19.95000
# District of Columbia    10.0   286.502000   547.419707     9.640    20.26500
# Florida                383.0   233.612815  1205.490630     1.167    11.95200
# Georgia                184.0   266.825217   637.796228     1.780    19.23000
# Idaho                   21.0   208.689810   282.061093     3.304    21.31200
# ...

# %%
df.groupby("Category")['Sales'].describe()
# Out:
#                   count        mean          std    min     25%      50%  \
# Category
# Furniture        2121.0  349.834887   503.179145  1.892  47.040  182.220
# Office Supplies  6026.0  119.324101   382.182228  0.444  11.760   27.418
# Technology       1847.0  452.709276  1108.655848  0.990  68.016  166.160
#
#                      75%        max
# Category
# Furniture        435.168   4416.174
# Office Supplies   79.920   9892.740
# Technology       448.534  22638.480

# %%
df.groupby("Category")['Profit'].describe()
# Out:
#                   count       mean         std        min       25%      50%  \
# Category
# Furniture        2121.0   8.699327  136.049246 -1862.3124 -12.84900   7.7748
# Office Supplies  6026.0  20.327050  164.887280 -3701.8928   2.10150   6.8824
# Technology       1847.0  78.752002  428.816633 -6599.9780   5.20365  25.0182
#
#                      75%       max
# Category
# Furniture        33.7266  1013.127
# Office Supplies  19.4163  4946.370
# Technology       74.8946  8399.976

# %%
#which category has the least profit margin- Furniture

# %%
import seaborn as sbn

# %%
sbn.catplot(
    data=df, kind="bar", x="Category", y="Sales")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))

sbn.scatterplot(x='Sales', y='Profit', data=df, hue='Sub-Category' )
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
#focus on copiers and stop selling machines

# %%
df.groupby("State")['Sales'].mean().sort_values(ascending= False).head(10) # sort in descreasing order of profit
# Out:
# State
# Wyoming         1603.136000
# Vermont          811.760909
# Nevada           428.951333
# Rhode Island     404.070643
# Montana          372.623467
# Indiana          359.431946
# Missouri         336.441667
# Minnesota        335.541011
# Alabama          319.846557
# Virginia         315.342500
# Name: Sales, dtype: float64

# %%
df.groupby("State")['Profit'].mean().sort_values(ascending= False).head(10) # sort in descreasing order of profit
# Out:
# State
# Vermont                 204.088936
# Rhode Island            130.100523
# Indiana                 123.375411
# Montana                 122.221900
# Minnesota               121.608847
# District of Columbia    105.958930
# Delaware                103.930988
# Wyoming                 100.196000
# Missouri                 97.518341
# Michigan                 95.934069
# Name: Profit, dtype: float64

# %%
df.groupby("State")['Profit'].mean().sort_values(ascending= True).head(10) # sort in increasing order of profit
# Out:
# State
# Ohio             -36.186304
# Colorado         -35.867351
# North Carolina   -30.083985
# Tennessee        -29.189583
# Pennsylvania     -26.507598
# Texas            -26.121174
# Illinois         -25.625787
# Arizona          -15.303235
# Oregon            -9.600569
# Florida           -8.875461
# Name: Profit, dtype: float64

# %%
#The above mentioned states have average profit in negative. The stores in these states are not profitable
